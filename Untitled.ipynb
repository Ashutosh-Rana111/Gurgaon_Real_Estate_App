# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('gurgaon_feature_selection.csv')
df.head()
# Out:
#   property_type      sector  price  bedRoom  bathroom balcony   agePossession  \
# 0          flat   sector 36   0.82        3         2       2    New Property
# 1          flat   sector 89   0.95        2         2       2    New Property
# 2          flat  sohna road   0.32        2         2       1    New Property
# 3          flat   sector 92   1.60        3         4      3+  Relatively New
# 4          flat  sector 102   0.48        2         2       1  Relatively New
#
#    built_up_area  study room  servant room  store room furnishing_type  \
# 0          850.0           0             0           0     unfurnished
# 1         1226.0           1             1           0     unfurnished
# 2         1000.0           0             0           0     unfurnished
# 3         1615.0           0             1           0   semifurnished
# 4          582.0           0             0           1     unfurnished
#
#   floor_category luxury_category
# 0            Low             Low
# ...

# %%
ast = df['sector'].unique()

# %%
stri = sorted(ast, key = len)

# %%
stri
# Out:
# ['manesar',
#  'sector 1',
#  'sector 2',
#  'sector 3',
#  'sector 4',
#  'sector 5',
#  'sector 6',
#  'sector 7',
#  'sector 8',
#  'sector 9',
#  'sector 10',
#  'sector 11',
#  'sector 12',
#  'sector 13',
#  'sector 14',
#  'sector 15',
#  'sector 17',
#  'sector 21',
#  'sector 22',
#  'sector 23',
#  'sector 24',
#  'sector 25',
#  'sector 26',
#  'sector 27',
#  'sector 28',
#  'sector 30',
#  'sector 31',
#  'sector 33',
#  'sector 36',
#  'sector 37',
#  'sector 38',
#  'sector 39',
#  'sector 40',
#  'sector 41',
#  'sector 43',
#  'sector 45',
#  'sector 46',
#  'sector 47',
#  'sector 48',
#  'sector 49',
#  'sector 50',
#  'sector 51',
#  'sector 52',
#  'sector 53',
#  'sector 54',
#  'sector 55',
#  'sector 56',
#  'sector 57',
#  'sector 58',
#  'sector 59',
#  'sector 60',
#  'sector 61',
#  'sector 62',
#  'sector 63',
#  'sector 65',
#  'sector 66',
#  'sector 67',
#  'sector 68',
#  'sector 69',
#  'sector 70',
#  'sector 71',
#  'sector 72',
#  'sector 73',
# ...

# %%
# Assuming your list is called 'sectors'
print("', '".join(stri))
# Out:
# manesar', 'sector 1', 'sector 2', 'sector 3', 'sector 4', 'sector 5', 'sector 6', 'sector 7', 'sector 8', 'sector 9', 'sector 10', 'sector 11', 'sector 12', 'sector 13', 'sector 14', 'sector 15', 'sector 17', 'sector 21', 'sector 22', 'sector 23', 'sector 24', 'sector 25', 'sector 26', 'sector 27', 'sector 28', 'sector 30', 'sector 31', 'sector 33', 'sector 36', 'sector 37', 'sector 38', 'sector 39', 'sector 40', 'sector 41', 'sector 43', 'sector 45', 'sector 46', 'sector 47', 'sector 48', 'sector 49', 'sector 50', 'sector 51', 'sector 52', 'sector 53', 'sector 54', 'sector 55', 'sector 56', 'sector 57', 'sector 58', 'sector 59', 'sector 60', 'sector 61', 'sector 62', 'sector 63', 'sector 65', 'sector 66', 'sector 67', 'sector 68', 'sector 69', 'sector 70', 'sector 71', 'sector 72', 'sector 73', 'sector 74', 'sector 76', 'sector 77', 'sector 78', 'sector 79', 'sector 80', 'sector 81', 'sector 82', 'sector 83', 'sector 84', 'sector 85', 'sector 86', 'sector 88', 'sector 89', 'sector 9
# ...
